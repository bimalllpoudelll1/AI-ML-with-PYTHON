# %%
import os #to import file path
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import dataloader, Dataset
from torchvision import transforms
from skimage.io import imread
from skimage.transform import resize
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
device=torch.device('cuba' if torch.cuda.is_available() else 'cpu')
print(f"rule:{device}")
# Out:
# rule:cpu

# %%
# creating brain of CNN -> for Image processing
# used to extrat feature
# it contains Convolution layers and Flatten layers
class parkingCNN(nn.Module):
    def __init__ (self):
        super(parkingCNN,self).__init__
        self.conv_layers=nn.Sequential(
            # 2d image
            nn.Conv2d(3,16, kernel_size=3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(16,32,kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2)
            
        )
        self.fc_layers=nn.Sequential(
            nn.Flatten(),
            # 32*3*32,32,64
            nn.Linear(288,64),
            nn.ReLU(),
            nn.Linear(64,2)
        )
        def forward(self,x):
            x=self.conv_layers(x)
            y=self.fc_layers(y)
            return x

# %%
# function to implort dataset
class parkingDataset(Dataset):
    def __init__(self, root_dir, categories):
        self.data=[]
        self.labels=[]
        for idx, cat in enumerate(categories):
            path=os.path.join(root_dir,cat)
            for f in os.listdir(path)[:500]:
                img=imread(os.path.join(path,f))
                self.data.append(resize(img(15,15)))
                self.labels.append(idx)
    def __len__(self):
        return len(self,data)
    def __getitem__(self, index):
        img=torch.tensor(self,data[idx]),permute(2,0,1).float()
        return img, self.labels[idx]

# %%
# training data
input_dir=""
categories=['empty','non_empty']

dataset= parkingDataset(input_dir, categories)
train_loader=dataloader(dataset, batch_size=32, shuttle=True)

# %%
# train CNN model
model=parkingDataset(input_dir, categories)
optimzer=optim.Adam(model.parameers,lr=0.001)
criterion=nn.CrossEntropyLoss()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 # train CNN model
# ----> 2 model=parkingDataset(input_dir, categories)
#       3 optimzer=optim.Adam(model.parameers,lr=0.001)
#       4 criterion=nn.CrossEntropyLoss()
#
# Cell In[12], line 8, in parkingDataset.__init__(self, root_dir, categories)
#       6 for idx, cat in enumerate(categories):
#       7     path=os.path.join(root_dir,cat)
# ----> 8     for f in os.listdir(path)[:500]:
#       9         img=imread(os.path.join(path,f))
#      10         self.data.append(resize(img(15,15)))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'empty'
